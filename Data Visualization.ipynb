# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
weather = pd.read_csv("project.csv")
weather
# Out:
#                         time  entry_id  temperature  humidity  co2ppm     type
# 0    2020-09-19 22:53:28 +06         1         32.0      90.0     927     Rain
# 1    2020-09-19 22:53:44 +06         2         32.0      90.0     928     Mist
# 2    2020-09-19 22:54:01 +06         3         32.0      92.0     925  Drizzle
# 3    2020-09-19 22:54:17 +06         4         32.0      93.0     929     Rain
# 4    2020-09-19 22:54:34 +06         5         32.0      93.0     930     Mist
# ..                       ...       ...          ...       ...     ...      ...
# 395  2020-09-23 13:45:54 +06       396         30.7      83.4     630  Drizzle
# 396  2020-09-23 13:46:14 +06       397         30.7      84.0     635     Rain
# 397  2020-09-23 13:46:29 +06       398         30.7      84.5     638  Drizzle
# 398  2020-09-23 13:46:50 +06       399         30.7      81.6     640     Rain
# 399  2020-09-23 13:47:05 +06       400         30.7      81.3     642  Drizzle
#
# [400 rows x 6 columns]

# %%
weather.head()
# Out:
#                       time  entry_id  temperature  humidity  co2ppm     type
# 0  2020-09-19 22:53:28 +06         1         32.0      90.0     927     Rain
# 1  2020-09-19 22:53:44 +06         2         32.0      90.0     928     Mist
# 2  2020-09-19 22:54:01 +06         3         32.0      92.0     925  Drizzle
# 3  2020-09-19 22:54:17 +06         4         32.0      93.0     929     Rain
# 4  2020-09-19 22:54:34 +06         5         32.0      93.0     930     Mist

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 6 columns):
# time           400 non-null object
# entry_id       400 non-null int64
# temperature    400 non-null float64
# humidity       400 non-null float64
# co2ppm         400 non-null int64
# type           400 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 18.9+ KB

# %%
sns.barplot(weather['temperature'], weather['humidity'])

# %%
sns.pairplot(weather[['humidity', 'temperature', 'co2ppm']])

# %%
sns.barplot(weather['temperature'], weather['co2ppm'])

# %%
sns.pointplot(weather['temperature'], weather['humidity'], hue=weather['type'])

# %%
sns.pointplot(weather['temperature'], weather['co2ppm'], hue=weather['type'])

# %%
sns.distplot(weather['humidity'])

# %%
sns.distplot(weather['temperature'])

# %%
sns.distplot(weather['co2ppm'])

# %%
sns.barplot(weather['type'], weather['co2ppm'])
