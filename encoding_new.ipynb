# %%
import pandas as pd

# %%
df = pd.read_csv("hard_mining.csv")
df
# Out:
#      location  bedrooms  age  floor  area  price
# 0   dhanmondi       1.0   10      2  1200  12000
# 1   dhanmondi       2.0   15      4  1400  11000
# 2   dhanmondi       2.0   21      8  1550  10000
# 3   dhanmondi       3.0   28      2  1680  13000
# 4   dhanmondi       3.0   15      6  1800  18000
# 5   dhanmondi       3.0   35      1  1950  25000
# 6   dhanmondi       4.0   32      5  2100  26000
# 7   dhanmondi       4.0   12      4  2300  28000
# 8   dhanmondi       NaN    8      8  2480  24000
# 9   dhanmondi       4.0   19      3  2550  30000
# 10  dhanmondi       NaN   30      4  2680  32000
# 11  dhanmondi       4.0   32      2  2900  36000
# 12  dhanmondi       NaN   12      1  3100  37000
# 13  dhanmondi       5.0   26      4  3300  42000
# 14  dhanmondi       5.0   15      6  3850  47000
# 15  dhanmondi       NaN   17      7  3900  43000
# 16  dhanmondi       5.0   13      9  4100  41000
# 17  dhanmondi       5.0    5     10  4200  49000
# ...

# %%
import math
median_bedrooms = math.floor(df.bedrooms.median())
median_bedrooms
# Out:
# 4

# %%
df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())
df
# Out:
#      location  bedrooms  age  floor  area  price
# 0   dhanmondi       1.0   10      2  1200  12000
# 1   dhanmondi       2.0   15      4  1400  11000
# 2   dhanmondi       2.0   21      8  1550  10000
# 3   dhanmondi       3.0   28      2  1680  13000
# 4   dhanmondi       3.0   15      6  1800  18000
# 5   dhanmondi       3.0   35      1  1950  25000
# 6   dhanmondi       4.0   32      5  2100  26000
# 7   dhanmondi       4.0   12      4  2300  28000
# 8   dhanmondi       4.0    8      8  2480  24000
# 9   dhanmondi       4.0   19      3  2550  30000
# 10  dhanmondi       4.0   30      4  2680  32000
# 11  dhanmondi       4.0   32      2  2900  36000
# 12  dhanmondi       4.0   12      1  3100  37000
# 13  dhanmondi       5.0   26      4  3300  42000
# 14  dhanmondi       5.0   15      6  3850  47000
# 15  dhanmondi       4.0   17      7  3900  43000
# 16  dhanmondi       5.0   13      9  4100  41000
# 17  dhanmondi       5.0    5     10  4200  49000
# ...

# %%
dummies = pd.get_dummies(df.location)
dummies
# Out:
#     banani  dhanmondi  zigatola
# 0        0          1         0
# 1        0          1         0
# 2        0          1         0
# 3        0          1         0
# 4        0          1         0
# 5        0          1         0
# 6        0          1         0
# 7        0          1         0
# 8        0          1         0
# 9        0          1         0
# 10       0          1         0
# 11       0          1         0
# 12       0          1         0
# 13       0          1         0
# 14       0          1         0
# 15       0          1         0
# 16       0          1         0
# 17       0          1         0
# 18       0          1         0
# 19       0          1         0
# 20       1          0         0
# 21       1          0         0
# 22       1          0         0
# 23       1          0         0
# 24       1          0         0
# 25       1          0         0
# 26       1          0         0
# 27       1          0         0
# ...

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#      location  bedrooms  age  floor  area  price  banani  dhanmondi  zigatola
# 0   dhanmondi       1.0   10      2  1200  12000       0          1         0
# 1   dhanmondi       2.0   15      4  1400  11000       0          1         0
# 2   dhanmondi       2.0   21      8  1550  10000       0          1         0
# 3   dhanmondi       3.0   28      2  1680  13000       0          1         0
# 4   dhanmondi       3.0   15      6  1800  18000       0          1         0
# 5   dhanmondi       3.0   35      1  1950  25000       0          1         0
# 6   dhanmondi       4.0   32      5  2100  26000       0          1         0
# 7   dhanmondi       4.0   12      4  2300  28000       0          1         0
# 8   dhanmondi       4.0    8      8  2480  24000       0          1         0
# 9   dhanmondi       4.0   19      3  2550  30000       0          1         0
# 10  dhanmondi       4.0   30      4  2680  32000       0          1         0
# ...

# %%
final = merged.drop(['location'], axis='columns')
final
# Out:
#     bedrooms  age  floor  area  price  banani  dhanmondi  zigatola
# 0        1.0   10      2  1200  12000       0          1         0
# 1        2.0   15      4  1400  11000       0          1         0
# 2        2.0   21      8  1550  10000       0          1         0
# 3        3.0   28      2  1680  13000       0          1         0
# 4        3.0   15      6  1800  18000       0          1         0
# 5        3.0   35      1  1950  25000       0          1         0
# 6        4.0   32      5  2100  26000       0          1         0
# 7        4.0   12      4  2300  28000       0          1         0
# 8        4.0    8      8  2480  24000       0          1         0
# 9        4.0   19      3  2550  30000       0          1         0
# 10       4.0   30      4  2680  32000       0          1         0
# 11       4.0   32      2  2900  36000       0          1         0
# 12       4.0   12      1  3100  37000       0          1         0
# ...

# %%
final = final.drop(['zigatola'], axis='columns')
final
# Out:
#     bedrooms  age  floor  area  price  banani  dhanmondi
# 0        1.0   10      2  1200  12000       0          1
# 1        2.0   15      4  1400  11000       0          1
# 2        2.0   21      8  1550  10000       0          1
# 3        3.0   28      2  1680  13000       0          1
# 4        3.0   15      6  1800  18000       0          1
# 5        3.0   35      1  1950  25000       0          1
# 6        4.0   32      5  2100  26000       0          1
# 7        4.0   12      4  2300  28000       0          1
# 8        4.0    8      8  2480  24000       0          1
# 9        4.0   19      3  2550  30000       0          1
# 10       4.0   30      4  2680  32000       0          1
# 11       4.0   32      2  2900  36000       0          1
# 12       4.0   12      1  3100  37000       0          1
# 13       5.0   26      4  3300  42000       0          1
# 14       5.0   15      6  3850  47000       0          1
# ...

# %%
x = final.drop('price', axis='columns')
x
# Out:
#     bedrooms  age  floor  area  banani  dhanmondi
# 0        1.0   10      2  1200       0          1
# 1        2.0   15      4  1400       0          1
# 2        2.0   21      8  1550       0          1
# 3        3.0   28      2  1680       0          1
# 4        3.0   15      6  1800       0          1
# 5        3.0   35      1  1950       0          1
# 6        4.0   32      5  2100       0          1
# 7        4.0   12      4  2300       0          1
# 8        4.0    8      8  2480       0          1
# 9        4.0   19      3  2550       0          1
# 10       4.0   30      4  2680       0          1
# 11       4.0   32      2  2900       0          1
# 12       4.0   12      1  3100       0          1
# 13       5.0   26      4  3300       0          1
# 14       5.0   15      6  3850       0          1
# 15       4.0   17      7  3900       0          1
# 16       5.0   13      9  4100       0          1
# 17       5.0    5     10  4200       0          1
# ...

# %%
y = final.price
y
# Out:
# 0     12000
# 1     11000
# 2     10000
# 3     13000
# 4     18000
# 5     25000
# 6     26000
# 7     28000
# 8     24000
# 9     30000
# 10    32000
# 11    36000
# 12    37000
# 13    42000
# 14    47000
# 15    43000
# 16    41000
# 17    49000
# 18    55000
# 19    65000
# 20    18000
# 21    25000
# 22    27000
# 23    31000
# 24    30000
# 25    29000
# 26    35000
# 27    42000
# 28    35000
# 29    45000
# 30    47000
# 31    39000
# 32    40000
# 33    66000
# 34    50000
# 35    45000
# 36    51000
# 37    49000
# 38    70000
# 39    10000
# 40    16000
# 41    14000
# 42    18000
# 43    22000
# 44    19000
# 45    28000
# 46    30000
# 47    35000
# 48    38000
# 49    40000
# 50    39000
# 51    49000
# 52    59000
# 53    61000
# 54    65000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.predict(x)
# Out:
# array([11590.03419793, 13143.08967791,  8104.98893656, 18321.67793554,
#        18074.99723179, 20433.63694142, 21145.11271278, 29787.11276622,
#        27737.29768914, 31695.31942164, 28829.62457553, 33012.69354622,
#        41654.69359966, 39554.19538325, 45629.98333004, 41028.48541881,
#        44995.93232352, 46921.65751502, 57836.64741481, 64502.8193822 ,
#        15601.08723543, 24664.13209147, 20403.67794013, 27718.17964834,
#        23946.39173022, 30226.06376202, 31126.59129259, 44041.87361971,
#        41138.81596177, 45472.49666936, 48801.24584873, 42024.23397503,
#        48059.37972402, 58030.83863123, 50499.1325105 , 51501.8263387 ,
#        53220.98123491, 49342.82881057, 68180.22297527, 14157.6646201 ,
#        18561.71435493, 24306.81546757, 17323.51049008, 22594.05278506,
#        19190.45917837, 25098.31893493, 25682.13531236, 34793.04536289,
#        40402.6709092 , 40894.53324927, 45014.24934614, 51154.97251327,
# ...

# %%
model.score(x,y)
# Out:
# 0.9321867223303033

# %%
model.predict([[4,32,5,2100,0,1]])
# Out:
# array([21145.11271278])

# %%
model.predict([[4,32,5,2100,1,0]])
# Out:
# array([25783.78084817])

# %%
model.predict([[1,10,2,1200,0,1]])
# Out:
# array([11590.03419793])

# %%
model.predict([[5,9,2,4100,0,0]])
# Out:
# array([56291.99975047])

# %%
model.predict([[5,9,2,4100,0,1]])
# Out:
# array([54743.13108061])

# %%
model.predict([[5,9,2,4100,1,0]])
# Out:
# array([59381.799216])

# %%
model.predict([[5,10,2,4100,0,0]])
# Out:
# array([56023.73403662])

# %%
model.score(x,y)
# Out:
# 0.9321867223303033
